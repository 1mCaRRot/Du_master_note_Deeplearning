# 599  5.9840  -27.0376  -15.3295  -12.8178  -33.6757 -59.05721  -36.82706
# 600  5.9923    7.5418    9.4779   28.9948   28.7546 -73.03295  -59.50285
#
#              4          4          4  ...       12       12        12  \
# ...

# %% [markdown]
# 这里开始将THz值取出，然后整合到一起，为后续三样条插值进行准备

# %%
a = filtered_df1.iloc[: , 0]
b = filtered_df2.iloc[: , 0]
c = filtered_df3.iloc[: , 0]

# %%
c
# Out:
# 1      1.0001
# 2      1.0084
# 3      1.0168
# 4      1.0251
# 5      1.0334
#         ...
# 596    5.9590
# 597    5.9673
# 598    5.9757
# 599    5.9840
# 600    5.9923
# Name: THz, Length: 600, dtype: float64

# %%
import numpy as np

x_original = np.concatenate((a, b, c))
x_guodu = np.unique(x_original)
x = np.sort(x_guodu)
print(f"合并后的数据（从小到大排序）：{x}\n这些数据共有{len(x)}个")
# Out:
# 合并后的数据（从小到大排序）：[1.0001   1.00672  1.00708  ... 5.9923   5.99328  5.996704]
# 这些数据共有1630个

# %%
# 这里命名中第一个字母表示对应的原本的THz值（上面的abc），第二个数字i表示是第i个化合物
a_8 = filtered_df1.iloc[ : , 1:11]
a_13 = filtered_df1.iloc[ : , 11:21]
a_14 = filtered_df1.iloc[ : , 21:31]
a_15 = filtered_df1.iloc[ : , 31:41]
a_16 = filtered_df1.iloc[ : , 41:51]
a_17 = filtered_df1.iloc[ : , 51:61]
a_18 = filtered_df1.iloc[ : , 61:71]
a_19 = filtered_df1.iloc[ : , 71:81]
a_20 = filtered_df1.iloc[ : , 81:91]

# %%
# 创建一个列表来存储切片
slices = []

# 使用for循环生成数据切片
for i in range(5):  # 0到4
    start_col = i * 10 + 1  # 起始列
    end_col = start_col + 10  # 结束列
    slices.append(filtered_df2.iloc[:, start_col:end_col])

# %%
b_1 = slices[0]
b_2 = slices[1]
b_3 = slices[2]
b_6 = slices[3]
b_7 = slices[4]

# %%
# 创建一个列表来存储切片
slices2 = []

# 使用for循环生成数据切片
for i in range(6):  # 0到5
    start_col = i * 10 + 1  # 起始列
    end_col = start_col + 10  # 结束列
    slices2.append(filtered_df3.iloc[:, start_col:end_col])

# %%
c_4 = slices2[0]
c_5 = slices2[1]
c_9 = slices2[2]
c_10 = slices2[3]
c_11 = slices2[4]
c_12 = slices2[5]

# %%
c_11
# Out:
#           11       11        11        11        11        11        11  \
# 1     3.3797   8.4009    3.4953   4.09598   3.34508   8.65760   8.38076
# 2     3.6990   7.3042    5.2514   4.41812   3.81291   7.95356   7.40600
# 3     5.0032   7.0944    6.5712   5.23200   4.90746   7.65970   7.01344
# 4     6.3128   7.2610    6.6804   6.21358   6.41657   7.80534   7.37503
# 5     7.7653   8.2380    6.2184   7.21880   7.60086   8.30216   8.17369
# ..       ...      ...       ...       ...       ...       ...       ...
# 596   1.6500 -18.2236  -65.8404 -45.66068 -24.54301 -34.20674 -19.42855
# 597 -88.3890 -65.3472  -73.2160 -35.50572 -55.86316 -23.63746 -45.76849
# 598 -49.6511 -25.0774  -75.5984 -51.82078 -54.50121 -37.97784 -34.47870
# 599 -24.3998 -19.6444    5.8687 -57.45497 -66.75487 -35.43947 -40.33259
# 600 -98.3140 -61.5966 -113.3813 -98.31400 -76.32811 -61.59660 -49.68562
#
#             11        11        11
# 1      3.56540   3.47434    3.4953
# ...

# %%
# 现在有了20种化合物各自的数据（前9列是训练数据，第10列是测试数据），还有了x轴的刻度。
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt
# 设置中文字体
plt.rcParams['font.family'] = 'SimHei'  # 使用黑体字体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# %%
# 创建三样条插值对象
cs1 = CubicSpline(b, b_1)

# 进行插值
b_1_new = cs1(x)

# 可视化插值结果
plt.figure(figsize=(4, 3), dpi=120)
plt.plot(b, b_1, 'o', label='Origin', color='red')
plt.plot(x, b_1_new, label='new', color='g')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()
plt.show()

# %%
# 创建三样条插值对象
b_2_train = b_2.iloc[:, 0: 9]
cs2 = CubicSpline(b, b_2)

# 进行插值
b_2_new = cs2(x)

# %%
# 创建三样条插值对象
b_3_train = b_3.iloc[:, 0: 9]
cs3 = CubicSpline(b, b_3)

# 进行插值
b_3_new = cs3(x)

# %%
# 创建三样条插值对象
b_6_train = b_6.iloc[:, 0: 9]
cs6 = CubicSpline(b, b_6)
b_7_train = b_7.iloc[:, 0: 9]
cs7 = CubicSpline(b, b_7)

# 进行插值
b_6_new = cs6(x)
b_7_new = cs7(x)

# %%
# 创建三样条插值对象
c_4_train = c_4.iloc[:, 0: 9]
cs4 = CubicSpline(c, c_4)
c_5_train = c_5.iloc[:, 0: 9]
cs5 = CubicSpline(c, c_5)
c_9_train = c_9.iloc[:, 0: 9]
cs9 = CubicSpline(c, c_9)
c_10_train = c_10.iloc[:, 0: 9]
cs10 = CubicSpline(c, c_10)
c_11_train = c_11.iloc[:, 0: 9]
cs11 = CubicSpline(c, c_11)
c_12_train = c_12.iloc[:, 0: 9]
cs12 = CubicSpline(c, c_12)

# 进行插值
c_4_new = cs4(x)
c_5_new = cs5(x)
c_9_new = cs9(x)
c_10_new = cs10(x)
c_11_new = cs11(x)
c_12_new = cs12(x)

# %%
# 创建三样条插值对象
a_8_train = a_8.iloc[:, 0: 9]
cs8 = CubicSpline(a, a_8)
a_13_train = a_13.iloc[:, 0: 9]
cs13 = CubicSpline(a, a_13)
a_14_train = a_14.iloc[:, 0: 9]
cs14 = CubicSpline(a, a_14)
a_15_train = a_15.iloc[:, 0: 9]
cs15 = CubicSpline(a, a_15)
a_16_train = a_16.iloc[:, 0: 9]
cs16 = CubicSpline(a, a_16)
a_17_train = a_17.iloc[:, 0: 9]
cs17 = CubicSpline(a, a_17)
a_18_train = a_18.iloc[:, 0: 9]
cs18 = CubicSpline(a, a_18)
a_19_train = a_19.iloc[:, 0: 9]
cs19 = CubicSpline(a, a_19)
a_20_train = a_20.iloc[:, 0: 9]
cs20 = CubicSpline(a, a_20)

# 进行插值
a_8_new = cs8(x)
a_13_new = cs13(x)
a_14_new = cs14(x)
a_15_new = cs15(x)
a_16_new = cs16(x)
a_17_new = cs17(x)
a_18_new = cs18(x)
a_19_new = cs19(x)
a_20_new = cs20(x)

# %% [markdown]
# 插值后原本的x轴就是x（整合到一起的THz数值），对应的值进行了插值，结果就是a_8_new等等的形式

# %%
a_8_new.shape
# Out:
# (1630, 10)

# %%
wokankan = pd.DataFrame(a_8_new)
wokankan
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.477477  0.476511  0.477268  0.477477  0.475474  0.464024  0.474922
# 1     0.475000  0.473950  0.474990  0.475000  0.472780  0.461260  0.472380
# 2     0.474856  0.473800  0.474851  0.474856  0.472628  0.461108  0.472240
# 3     0.474320  0.473244  0.474330  0.474320  0.472065  0.460548  0.471722
# 4     0.471580  0.470429  0.471588  0.471580  0.469283  0.457835  0.469202
# ...        ...       ...       ...       ...       ...       ...       ...
# 1625  0.715778  0.708987  0.715252  0.715778  0.610226  0.497560  0.583874
# 1626  0.740934  0.735295  0.740014  0.740935  0.615436  0.497738  0.593684
# 1627  0.756283  0.752437  0.755089  0.756283  0.617676  0.497875  0.600156
# 1628  0.760840  0.757730  0.759560  0.760840  0.618190  0.497920  0.602160
# 1629  0.776342  0.776587  0.774757  0.776340  0.619374  0.498092  0.609298
#
#              7         8         9
# ...

# %%
x.T
# Out:
# array([1.0001  , 1.00672 , 1.00708 , ..., 5.9923  , 5.99328 , 5.996704])

# %%
data = pd.DataFrame(x, columns=["THz"])
data
# Out:
#            THz
# 0     1.000100
# 1     1.006720
# 2     1.007080
# 3     1.008400
# 4     1.014709
# ...        ...
# 1625  5.984000
# 1626  5.989075
# 1627  5.992300
# 1628  5.993280
# 1629  5.996704
#
# [1630 rows x 1 columns]

# %%
# 创建20个列表，用于作为列名称
for i in range(1, 21):
    globals()[f'quanshi{i}'] = [f"化合物{i}" for _ in range(10)]

# 打印结果以验证
for i in range(1, 21):
    print(f"quanshi{i} =", globals()[f'quanshi{i}'])
# Out:
# quanshi1 = ['化合物1', '化合物1', '化合物1', '化合物1', '化合物1', '化合物1', '化合物1', '化合物1', '化合物1', '化合物1']
# quanshi2 = ['化合物2', '化合物2', '化合物2', '化合物2', '化合物2', '化合物2', '化合物2', '化合物2', '化合物2', '化合物2']
# quanshi3 = ['化合物3', '化合物3', '化合物3', '化合物3', '化合物3', '化合物3', '化合物3', '化合物3', '化合物3', '化合物3']
# quanshi4 = ['化合物4', '化合物4', '化合物4', '化合物4', '化合物4', '化合物4', '化合物4', '化合物4', '化合物4', '化合物4']
# quanshi5 = ['化合物5', '化合物5', '化合物5', '化合物5', '化合物5', '化合物5', '化合物5', '化合物5', '化合物5', '化合物5']
# quanshi6 = ['化合物6', '化合物6', '化合物6', '化合物6', '化合物6', '化合物6', '化合物6', '化合物6', '化合物6', '化合物6']
# quanshi7 = ['化合物7', '化合物7', '化合物7', '化合物7', '化合物7', '化合物7', '化合物7', '化合物7', '化合物7', '化合物7']
# quanshi8 = ['化合物8', '化合物8', '化合物8', '化合物8', '化合物8', '化合物8', '化合物8', '化合物8', '化合物8', '化合物8']
# quanshi9 = ['化合物9', '化合物9', '化合物9', '化合物9', '化合物9', '化合物9', '化合物9', '化合物9', '化合物9', '化合物9']
# quanshi10 = ['化合物10', '化合物10', '化合物10', '化合物10', '化合物10', '化合物10', '化合物10', '化合物10', '化合物10', '化合物10']
# ...

# %%
huahewu1 = pd.DataFrame(b_1_new, columns=quanshi1)
huahewu2 = pd.DataFrame(b_2_new, columns=quanshi2)
huahewu3 = pd.DataFrame(b_3_new, columns=quanshi3)
huahewu6 = pd.DataFrame(b_6_new, columns=quanshi6)
huahewu7 = pd.DataFrame(b_7_new, columns=quanshi7)

huahewu4 = pd.DataFrame(c_4_new, columns=quanshi4)
huahewu5 = pd.DataFrame(c_5_new, columns=quanshi5)
huahewu9 = pd.DataFrame(c_9_new, columns=quanshi9)
huahewu10 = pd.DataFrame(c_10_new, columns=quanshi10)
huahewu11 = pd.DataFrame(c_11_new, columns=quanshi11)
huahewu12 = pd.DataFrame(c_12_new, columns=quanshi12)

huahewu8 = pd.DataFrame(a_8_new, columns=quanshi8)
huahewu13 = pd.DataFrame(a_13_new, columns=quanshi13)
huahewu14 = pd.DataFrame(a_14_new, columns=quanshi14)
huahewu15 = pd.DataFrame(a_15_new, columns=quanshi15)
huahewu16 = pd.DataFrame(a_16_new, columns=quanshi16)
huahewu17 = pd.DataFrame(a_17_new, columns=quanshi17)
huahewu18 = pd.DataFrame(a_18_new, columns=quanshi18)
huahewu19 = pd.DataFrame(a_19_new, columns=quanshi19)
huahewu20 = pd.DataFrame(a_20_new, columns=quanshi20)

# %%
data = pd.concat([data, huahewu1, huahewu2, huahewu3, huahewu4, huahewu5, huahewu6, huahewu7, huahewu8, huahewu9, huahewu10, huahewu11, huahewu12], axis=1)
data
# Out:
#            THz       化合物1       化合物1       化合物1       化合物1       化合物1  \
# 0     1.000100  25.003755  15.424768  15.014877  14.915264  12.745902
# 1     1.006720  16.991687  15.923654  15.770497  15.393188  15.562738
# 2     1.007080  16.774730  15.948940  15.810440  15.418700  15.660120
# 3     1.008400  16.134590  16.040050  15.955136  15.511897  15.976300
# 4     1.014709  15.660120  16.441110  16.592820  15.951410  16.774730
# ...        ...        ...        ...        ...        ...        ...
# 1625  5.984000  50.132910  47.932195  42.687858  44.680172  44.172638
# 1626  5.989075  49.471650  46.740080  42.830230  45.769400  46.015580
# 1627  5.992300  46.750137  45.395538  43.288397  46.833510  47.220886
# 1628  5.993280  45.609578  44.975750  43.480323  47.173097  47.473722
# 1629  5.996704  40.599770  43.706150  44.331980  48.295520  47.585010
#
#            化合物1       化合物1       化合物1       化合物1  ...      化合物12       化合物12  \
# ...

# %%
data = pd.concat([data, huahewu13, huahewu14, huahewu15, huahewu16, huahewu17, huahewu18, huahewu19, huahewu20], axis=1)
data
# Out:
#            THz       化合物1       化合物1       化合物1       化合物1       化合物1  \
# 0     1.000100  25.003755  15.424768  15.014877  14.915264  12.745902
# 1     1.006720  16.991687  15.923654  15.770497  15.393188  15.562738
# 2     1.007080  16.774730  15.948940  15.810440  15.418700  15.660120
# 3     1.008400  16.134590  16.040050  15.955136  15.511897  15.976300
# 4     1.014709  15.660120  16.441110  16.592820  15.951410  16.774730
# ...        ...        ...        ...        ...        ...        ...
# 1625  5.984000  50.132910  47.932195  42.687858  44.680172  44.172638
# 1626  5.989075  49.471650  46.740080  42.830230  45.769400  46.015580
# 1627  5.992300  46.750137  45.395538  43.288397  46.833510  47.220886
# 1628  5.993280  45.609578  44.975750  43.480323  47.173097  47.473722
# 1629  5.996704  40.599770  43.706150  44.331980  48.295520  47.585010
#
#            化合物1       化合物1       化合物1       化合物1  ...     化合物20     化合物20  \
# ...

# %%
data.to_excel('插值整合后的数据.xlsx', index=False, engine='openpyxl')
