# %%
import pandas as pd

df1 = pd.read_excel("28672.xlsx", sheet_name='Sheet1')
df2 = pd.read_excel("7269.xlsx", sheet_name='Sheet1')
df3 = pd.read_excel("917.xlsx", sheet_name='Sheet1')

# %%
# 这里的代码都同“插值处理.ipynb”，只是为了将有效数据取出，并加上列的名称方便查看
df1 = df1[:430]
df3 = df3[:709]
columns1 = ["THz"] + ["8"]*10 + ["13"]*10 + ["14"]*10 + ["15"]*10 + ["16"]*10 + ["17"]*10 + ["18"]*10 + ["19"]*10 + ["20"]*10
columns2 = ["THz"] + ["1"]*10 + ["2"]*10 + ["3"]*10 + ["6"]*10 + ["7"]*10
columns3 = ["THz"] + ["4"]*10 + ["5"]*10 + ["9"]*10 + ["10"]*10 + ["11"]*10 + ["12"]*10
df1.columns = columns1
df2.columns = columns2
df3.columns = columns3

# %%
df1
# Out:
#          THz        8        8        8        8        8        8        8  \
# 0    0.28672  0.36798  0.36798  0.36647  0.36798  0.46638  0.36203  0.34806
# 1    0.30000  0.36009  0.36424  0.36352  0.36465  0.44765  0.36784  0.35645
# 2    0.31328  0.36465  0.36628  0.36343  0.36798  0.42622  0.37361  0.36468
# 3    0.32672  0.36798  0.36834  0.36756  0.36798  0.40644  0.37943  0.37282
# 4    0.34000  0.37069  0.37420  0.37128  0.37069  0.39166  0.38515  0.38069
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 425  5.95328  0.54747  0.54848  0.54743  0.54747  0.53674  0.49735  0.53383
# 426  5.96656  0.62236  0.61987  0.62254  0.62236  0.57694  0.49727  0.55355
# 427  5.98000  0.69519  0.68861  0.69493  0.69519  0.60468  0.49745  0.57646
# 428  5.99328  0.76084  0.75773  0.75956  0.76084  0.61819  0.49792  0.60216
# 429  6.00656  0.81717  0.81717  0.81785  0.81717  0.61797   0.4987  0.63105
#
# ...

# %%
df2
# Out:
#            THz          1         1         1         1         1        1  \
# 0     0.007629   0.730346   7.63251   5.77874   0.73035   0.73035  3.86332
# 1     0.015259   5.207089   7.10915  11.15187   4.94761   5.20709  4.37826
# 2     0.022888   8.905381   6.63559  14.09222   8.30606   8.90538  5.03519
# 3     0.030518  11.773360   6.21183  13.92353  10.78522  11.77336  5.85410
# 4     0.038147  14.914100   5.83788  10.75217   4.11850   8.90538  6.85232
# ...        ...        ...       ...       ...       ...       ...      ...
# 1043  7.965088 -16.619680 -10.09624 -13.67497  -4.29490  -2.38553 -3.78715
# 1044  7.972717 -20.406900  -9.62705 -14.69169  -8.81213  -8.55413 -3.66872
# 1045  7.980347  -8.554134  -7.66708 -12.36755  -8.02005  -8.55413 -3.50927
# 1046  7.987976   3.870465  -4.21633  -7.36875  -1.02456   1.61000 -3.29147
# 1047  7.995605   1.609997   0.72519  -0.85780   1.61000   1.61000 -2.99585
#
# ...

# %%
df3
# Out:
#         THz        4        4        4        4         4         4         4  \
# 0    0.0917  16.6037  14.5181  13.7532  12.7719  18.64499  16.25848  13.48349
# 1    0.1000  17.0103  16.1739  11.9931  13.1101  17.50670  15.63763  13.35862
# 2    0.1083  18.0552  18.8897  13.1453  18.1000  16.50203  15.30838  13.19093
# 3    0.1167  15.8848  15.4193  15.0953  15.4061  15.63099  15.27075  12.98043
# 4    0.1250  14.0509  13.7552  11.6317  12.0420  14.89356  15.52474  12.72711
# ..      ...      ...      ...      ...      ...       ...       ...       ...
# 704  5.9590 -20.0564  -6.8289 -13.2030   5.4548 -24.47250   3.20358  -0.36771
# 705  5.9673 -11.6980  45.1276  -0.7738   2.8223 -35.26734  -3.64783  -6.22492
# 706  5.9757 -25.3854 -11.2433 -13.9804   1.8767 -44.75634 -19.39213 -14.02231
# 707  5.9840 -27.0376 -15.3295 -12.8178 -33.6757 -59.05721 -36.82706 -25.70909
# 708  5.9923   7.5418   9.4779  28.9948  28.7546 -73.03295 -59.50285 -41.10221
#
# ...

# %%
# 只取 1-3 THz的数据
filtered_df1 = df1[(df1['THz'] > 1) & (df1['THz'] < 3)]
filtered_df2 = df2[(df2['THz'] > 1) & (df2['THz'] < 3)]
filtered_df3 = df3[(df3['THz'] > 1) & (df3['THz'] < 3)]

# %%
filtered_df1
# Out:
#          THz        8        8        8        8        8        8        8  \
# 54   1.00672  0.47500  0.47395  0.47499    0.475  0.47278  0.46126  0.47238
# 55   1.02000  0.46906  0.46791  0.46901  0.46906  0.46685  0.45551  0.46702
# 56   1.03328  0.46186  0.46127  0.46172  0.46186  0.46047  0.44946  0.46123
# 57   1.04672  0.45374  0.45448  0.45388  0.45374  0.45377  0.44302  0.45485
# 58   1.06000  0.44669  0.44751  0.44695  0.44669  0.44683  0.43639    0.448
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 199  2.94000  0.31783  0.31517  0.31763  0.31783  0.31182  0.27918   0.3067
# 200  2.95328  0.30838  0.30655  0.30842  0.30838  0.30348  0.27207   0.2964
# 201  2.96656  0.29719  0.29612  0.29731  0.29719  0.29347  0.26467  0.28481
# 202  2.98000  0.28521  0.28404  0.28517  0.28521   0.2817    0.257  0.27194
# 203  2.99328  0.27197  0.27064  0.27199  0.27197   0.2682  0.24938  0.25832
#
# ...

# %%
filtered_df1_index = [i for i in range(1, 151)]
filtered_df1.index = filtered_df1_index

# %%
filtered_df1
# Out:
#          THz        8        8        8        8        8        8        8  \
# 1    1.00672  0.47500  0.47395  0.47499    0.475  0.47278  0.46126  0.47238
# 2    1.02000  0.46906  0.46791  0.46901  0.46906  0.46685  0.45551  0.46702
# 3    1.03328  0.46186  0.46127  0.46172  0.46186  0.46047  0.44946  0.46123
# 4    1.04672  0.45374  0.45448  0.45388  0.45374  0.45377  0.44302  0.45485
# 5    1.06000  0.44669  0.44751  0.44695  0.44669  0.44683  0.43639    0.448
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 146  2.94000  0.31783  0.31517  0.31763  0.31783  0.31182  0.27918   0.3067
# 147  2.95328  0.30838  0.30655  0.30842  0.30838  0.30348  0.27207   0.2964
# 148  2.96656  0.29719  0.29612  0.29731  0.29719  0.29347  0.26467  0.28481
# 149  2.98000  0.28521  0.28404  0.28517  0.28521   0.2817    0.257  0.27194
# 150  2.99328  0.27197  0.27064  0.27199  0.27197   0.2682  0.24938  0.25832
#
# ...

# %%
filtered_df2
# Out:
#           THz          1          1          1          1          1  \
# 131  1.007080   16.77473   15.94894   15.81044   15.41870   15.66012
# 132  1.014709   15.66012   16.44111   16.59282   15.95141   16.77473
# 133  1.022339   17.47663   16.85202   17.17888   16.47655   16.90235
# 134  1.029968   17.81482   17.17835   17.48577   17.00511   17.06807
# 135  1.037598   16.90235   17.41314   17.55601   17.54017   17.47663
# ..        ...        ...        ...        ...        ...        ...
# 388  2.967834  122.39390  118.78227  120.17072  119.43395  119.95100
# 389  2.975464  110.57740  120.28499  120.08353  117.62299  115.98170
# 390  2.983093  126.40470  119.79745  119.69084  117.64459  115.98170
# 391  2.990723  132.87290  120.19005  119.17762  117.02776  115.98170
# 392  2.998352  115.98170  117.98792  118.44139  117.84326  115.98170
#
#              1          1          1          1  ...          7          7  \
# ...

# %%
filtered_df2_index = [i for i in range(1, 263)]
filtered_df2.index = filtered_df2_index

# %%
filtered_df2
# Out:
#           THz          1          1          1          1          1  \
# 1    1.007080   16.77473   15.94894   15.81044   15.41870   15.66012
# 2    1.014709   15.66012   16.44111   16.59282   15.95141   16.77473
# 3    1.022339   17.47663   16.85202   17.17888   16.47655   16.90235
# 4    1.029968   17.81482   17.17835   17.48577   17.00511   17.06807
# 5    1.037598   16.90235   17.41314   17.55601   17.54017   17.47663
# ..        ...        ...        ...        ...        ...        ...
# 258  2.967834  122.39390  118.78227  120.17072  119.43395  119.95100
# 259  2.975464  110.57740  120.28499  120.08353  117.62299  115.98170
# 260  2.983093  126.40470  119.79745  119.69084  117.64459  115.98170
# 261  2.990723  132.87290  120.19005  119.17762  117.02776  115.98170
# 262  2.998352  115.98170  117.98792  118.44139  117.84326  115.98170
#
#              1          1          1          1  ...          7          7  \
# ...

# %%
filtered_df3
# Out:
#         THz         4         4         4         4         4          4  \
# 109  1.0001   94.4542  111.6921  104.5103  116.3439  97.64695  111.10802
# 110  1.0084   93.2520  106.7537  109.9315  108.2626  97.75517  117.09985
# 111  1.0168  100.9262  113.2655  115.0848  110.9267  98.77160  119.48785
# 112  1.0251   96.9626  141.8257  110.3610  110.0188  97.68198  124.26215
# 113  1.0334   97.1154  131.6016  136.6646  113.6484  97.49472  125.71076
# ..      ...       ...       ...       ...       ...       ...        ...
# 344  2.9587   20.2658   24.6214   53.7898   42.3851  29.52703   33.14821
# 345  2.9670   -4.2696    2.5030   -6.7783   -7.5308  28.47526   27.75690
# 346  2.9753  -20.5520  -11.9334  -19.1438   -7.1148  21.77595   20.50164
# 347  2.9837   42.3211   25.3862   25.6538   34.1748  17.25242   14.46244
# 348  2.9920    9.9587   35.8502   52.9184   49.1987  15.73727   10.88037
#
#              4          4          4  ...       12       12        12  \
# ...

# %%
filtered_df3_index = [i for i in range(1, 241)]
filtered_df3.index = filtered_df3_index

# %%
filtered_df3
# Out:
#         THz         4         4         4         4         4          4  \
# 1    1.0001   94.4542  111.6921  104.5103  116.3439  97.64695  111.10802
# 2    1.0084   93.2520  106.7537  109.9315  108.2626  97.75517  117.09985
# 3    1.0168  100.9262  113.2655  115.0848  110.9267  98.77160  119.48785
# 4    1.0251   96.9626  141.8257  110.3610  110.0188  97.68198  124.26215
# 5    1.0334   97.1154  131.6016  136.6646  113.6484  97.49472  125.71076
# ..      ...       ...       ...       ...       ...       ...        ...
# 236  2.9587   20.2658   24.6214   53.7898   42.3851  29.52703   33.14821
# 237  2.9670   -4.2696    2.5030   -6.7783   -7.5308  28.47526   27.75690
# 238  2.9753  -20.5520  -11.9334  -19.1438   -7.1148  21.77595   20.50164
# 239  2.9837   42.3211   25.3862   25.6538   34.1748  17.25242   14.46244
# 240  2.9920    9.9587   35.8502   52.9184   49.1987  15.73727   10.88037
#
#              4          4          4  ...       12       12        12  \
# ...

# %%
from sklearn.metrics import r2_score

# 选择观测数据和拟合数据
huahewu1_observed_data = filtered_df2.iloc[:, 1]  # 第二列是观测数据
huahewu1_fitted_data = filtered_df2.iloc[:, 10]    # 第十一列是拟合数据

# 计算R²值
huahewu1_rfang = r2_score(huahewu1_observed_data, huahewu1_fitted_data)

# 打印R²值
print(f"化合物1的R²值为: {huahewu1_rfang}")
# Out:
# 化合物1的R²值为: 0.9430957819714735

# %%
# 选择观测数据和拟合数据
huahewu8_observed_data = filtered_df1.iloc[:, 1]
huahewu8_fitted_data = filtered_df1.iloc[:, 10]
huahewu13_observed_data = filtered_df1.iloc[:, 11]
huahewu13_fitted_data = filtered_df1.iloc[:, 20]
huahewu14_observed_data = filtered_df1.iloc[:, 21]
huahewu14_fitted_data = filtered_df1.iloc[:, 30]
huahewu15_observed_data = filtered_df1.iloc[:, 31]
huahewu15_fitted_data = filtered_df1.iloc[:, 40]
huahewu16_observed_data = filtered_df1.iloc[:, 41]
huahewu16_fitted_data = filtered_df1.iloc[:, 50]
huahewu17_observed_data = filtered_df1.iloc[:, 51]
huahewu17_fitted_data = filtered_df1.iloc[:, 60]
huahewu18_observed_data = filtered_df1.iloc[:, 61]
huahewu18_fitted_data = filtered_df1.iloc[:, 70]
huahewu19_observed_data = filtered_df1.iloc[:, 71]
huahewu19_fitted_data = filtered_df1.iloc[:, 80]
huahewu20_observed_data = filtered_df1.iloc[:, 81]
huahewu20_fitted_data = filtered_df1.iloc[:, 90]

huahewu2_observed_data = filtered_df2.iloc[:, 11]
huahewu2_fitted_data = filtered_df2.iloc[:, 20]
huahewu3_observed_data = filtered_df2.iloc[:, 21]
huahewu3_fitted_data = filtered_df2.iloc[:, 30]
huahewu6_observed_data = filtered_df2.iloc[:, 31]
huahewu6_fitted_data = filtered_df2.iloc[:, 40]
huahewu7_observed_data = filtered_df2.iloc[:, 41]
huahewu7_fitted_data = filtered_df2.iloc[:, 50]

huahewu4_observed_data = filtered_df3.iloc[:, 1]
huahewu4_fitted_data = filtered_df3.iloc[:, 10]
huahewu5_observed_data = filtered_df3.iloc[:, 11]
huahewu5_fitted_data = filtered_df3.iloc[:, 20]
huahewu9_observed_data = filtered_df3.iloc[:, 21]
huahewu9_fitted_data = filtered_df3.iloc[:, 30]
huahewu10_observed_data = filtered_df3.iloc[:, 31]
huahewu10_fitted_data = filtered_df3.iloc[:, 40]
huahewu11_observed_data = filtered_df3.iloc[:, 41]
huahewu11_fitted_data = filtered_df3.iloc[:, 50]
huahewu12_observed_data = filtered_df3.iloc[:, 51]
huahewu12_fitted_data = filtered_df3.iloc[:, 60]

# 计算R²值
huahewu8_rfang = r2_score(huahewu8_observed_data, huahewu8_fitted_data)
huahewu13_rfang = r2_score(huahewu13_observed_data, huahewu13_fitted_data)
huahewu14_rfang = r2_score(huahewu14_observed_data, huahewu14_fitted_data)
huahewu15_rfang = r2_score(huahewu15_observed_data, huahewu15_fitted_data)
huahewu16_rfang = r2_score(huahewu16_observed_data, huahewu16_fitted_data)
huahewu17_rfang = r2_score(huahewu17_observed_data, huahewu17_fitted_data)
huahewu18_rfang = r2_score(huahewu18_observed_data, huahewu18_fitted_data)
huahewu19_rfang = r2_score(huahewu19_observed_data, huahewu19_fitted_data)
huahewu20_rfang = r2_score(huahewu20_observed_data, huahewu20_fitted_data)

huahewu2_rfang = r2_score(huahewu2_observed_data, huahewu2_fitted_data)
huahewu3_rfang = r2_score(huahewu3_observed_data, huahewu3_fitted_data)
huahewu6_rfang = r2_score(huahewu6_observed_data, huahewu6_fitted_data)
huahewu7_rfang = r2_score(huahewu7_observed_data, huahewu7_fitted_data)

huahewu4_rfang = r2_score(huahewu4_observed_data, huahewu4_fitted_data)
huahewu5_rfang = r2_score(huahewu5_observed_data, huahewu5_fitted_data)
huahewu9_rfang = r2_score(huahewu9_observed_data, huahewu9_fitted_data)
huahewu10_rfang = r2_score(huahewu10_observed_data, huahewu10_fitted_data)
huahewu11_rfang = r2_score(huahewu11_observed_data, huahewu11_fitted_data)
huahewu12_rfang = r2_score(huahewu12_observed_data, huahewu12_fitted_data)

# %%
# 使用列表推导式将所有变量的值添加到列表中
r_squared_values = [globals()[f'huahewu{i}_rfang'] for i in range(1, 21)]

# 打印列表中的R²值
for i in range(20):
    print(f"化合物{i + 1}的R²值为: {r_squared_values[i]}")
# Out:
# 化合物1的R²值为: 0.9430957819714735
# 化合物2的R²值为: 0.896803744138327
# 化合物3的R²值为: 0.9962822747218092
# 化合物4的R²值为: 0.645845494211107
# 化合物5的R²值为: 0.5811037574567798
# 化合物6的R²值为: 0.9998298831418005
# 化合物7的R²值为: 0.9771233363428274
# 化合物8的R²值为: 0.699968337396919
# 化合物9的R²值为: -0.5518284973296768
# 化合物10的R²值为: 0.7902504031061688
# 化合物11的R²值为: 0.7669670796439847
# 化合物12的R²值为: 0.6671393168158952
# 化合物13的R²值为: 0.9992306327280855
# 化合物14的R²值为: 0.9999905263498581
# 化合物15的R²值为: 0.9707700930252456
# 化合物16的R²值为: 0.6027170717980137
# 化合物17的R²值为: 0.3553822831011585
# 化合物18的R²值为: -0.1402430138778934
# 化合物19的R²值为: 0.6419858425730899
# 化合物20的R²值为: -20.648355231131138
